# %%
import requests
import json

headers = {'Authorization': f"Bearer {'1dMQ2EAJF6WO0A6-_L1sqZvTwYbtqgwziigGJb-m0XMW-JKXlFWreCbmGZ31rzU7gf77Je9Ucp0CYGqMAXtnhFQdInUcbOmQX7djrae96nmB0wvJQ2P6nXKomfhhXHYx'}"}

r1 = requests.get('https://api.yelp.com/v3/autocomplete?text=del&latitude=37.786882&longitude=-122.399972',headers=headers)
r1.json()
# Out:
# {'categories': [{'alias': 'delis', 'title': 'Delis'},
#   {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#   {'alias': 'couriers', 'title': 'Couriers & Delivery Services'}],
#  'businesses': [],
#  'terms': [{'text': 'Delivery'},
#   {'text': 'Pizza Delivery'},
#   {'text': 'Delivery Food'}]}

# %%
r2 = requests.get('https://api.yelp.com/v3/businesses/search?term=delis&latitude=37.786882&longitude=-122.399972',headers=headers)
r2.json()
# Out:
# {'businesses': [{'id': 'FmGF1B-Rpsjq1f5b56qMwg',
#    'alias': 'molinari-delicatessen-san-francisco',
#    'name': 'Molinari Delicatessen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6He-NlZrAv2mDV-yg6jW3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/molinari-delicatessen-san-francisco?adjust_creative=uoxFg3N3Pequsoz5IQRt8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=uoxFg3N3Pequsoz5IQRt8Q',
#    'review_count': 1040,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.79838, 'longitude': -122.40782},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '373 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['373 Columbus Ave', 'San Francisco, CA 94133']},
# ...

# %%
r3 = requests.get('https://api.yelp.com/v3/businesses/FmGF1B-Rpsjq1f5b56qMwg/reviews',headers=headers)
r3.json()
# Out:
# {'reviews': [{'id': 'bE6qagfh1C44ZTH8y8YEXQ',
#    'url': 'https://www.yelp.com/biz/molinari-delicatessen-san-francisco?adjust_creative=uoxFg3N3Pequsoz5IQRt8Q&hrid=bE6qagfh1C44ZTH8y8YEXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=uoxFg3N3Pequsoz5IQRt8Q',
#    'text': "Even though I lived not far from SF for many years, it took a Hawaii boy to teach me about Molinari's. After he mentioned that it's a required stop to get...",
#    'rating': 5,
#    'time_created': '2019-01-30 16:19:46',
#    'user': {'id': '88efmQyULvBHe6Y6D-8R4g',
#     'profile_url': 'https://www.yelp.com/user_details?userid=88efmQyULvBHe6Y6D-8R4g',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/8DIQ0PvYxFdiuxMO19L9QA/o.jpg',
#     'name': 'Teri Y.'}},
#   {'id': 'P7Z93x29c4i_99jNg5jPkw',
# ...

# %%
r3.status_code
r3=r3.json()

# %%
r3['reviews'][1]['text']
# Out:
# 'Sad  how times have changed. Gone is the great sandwiches and service at this old haunt of mine for the last forty years. No longer are there familiar faces...'

# %%
for item in range(1,3):
    print(r3['reviews'][item]['text'],'\n------')
# Out:
# Sad  how times have changed. Gone is the great sandwiches and service at this old haunt of mine for the last forty years. No longer are there familiar faces...
# ------
# Wow this place is so adorable, feels like a mom and pop shop. I went in yesterday around 215 and came out at 245, the line was quite long
#
# I ordered the...
# ------
